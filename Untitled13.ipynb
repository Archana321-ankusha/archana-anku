# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
df = pd.read_csv("C:/Users/ankus/OneDrive/Desktop/mtcars.csv")

plt.hist(df['mpg'], bins=10, edgecolor='black')
plt.title('Histogram of MPG')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

hist, bin_edges = np.histogram(df['mpg'], bins=10)
max_freq_bin = bin_edges[np.argmax(hist)]
print(max_freq_bin)
# Out:
# 15.100000000000001

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("C:/Users/ankus/OneDrive/Desktop/mtcars.csv")

plt.scatter(df['wt'], df['mpg'])
plt.title('Scatter Plot of Weight vs MPG')
plt.xlabel('Weight (1000 lbs)')
plt.ylabel('MPG')
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data for mpg
mpg_data = [18, 22, 24, 24, 25, 27, 29, 30, 32, 35, 40, 42]

# Convert to a pandas DataFrame for easier manipulation
df = pd.DataFrame(mpg_data, columns=['mpg'])

# Create the box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['mpg'])
plt.title('Box Plot of MPG')
plt.xlabel('MPG')
plt.show()

# Calculate the five-number summary
min_val = np.min(mpg_data)
q1 = np.percentile(mpg_data, 25)
median = np.median(mpg_data)
q3 = np.percentile(mpg_data, 75)
max_val = np.max(mpg_data)

print("Five-Number Summary:")
print(f"Minimum: {min_val}")
print(f"First Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"Third Quartile (Q3): {q3}")
print(f"Maximum: {max_val}")

# Optional: Display summary statistics for further insight
summary_stats = df.describe()
print("\nSummary Statistics:")
print(summary_stats)
# Out:
# Five-Number Summary:
# Minimum: 18
# First Quartile (Q1): 24.0
# Median (Q2): 28.0
# Third Quartile (Q3): 32.75
# Maximum: 42
#
# Summary Statistics:
#              mpg
# count  12.000000
# mean   29.000000
# std     7.236272
# min    18.000000
# 25%    24.000000
# 50%    28.000000
# 75%    32.750000
# max    42.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:/Users/ankus/OneDrive/Desktop/mtcars.csv")

# Create a box plot for the 'mpg' column
plt.figure(figsize=(8, 6))
plt.boxplot(df['mpg'], vert=False, patch_artist=True, 
            boxprops=dict(facecolor='lightblue', color='black'), 
            whiskerprops=dict(color='black'), 
            capprops=dict(color='black'), 
            medianprops=dict(color='red'))
plt.title('Box Plot of MPG')
plt.xlabel('Miles Per Gallon (MPG)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Calculate the five-number summary
min_val = df['mpg'].min()
q1 = df['mpg'].quantile(0.25)
median = df['mpg'].median()
q3 = df['mpg'].quantile(0.75)
max_val = df['mpg'].max()

# Print the five-number summary
print(f"Minimum: {min_val}")
print(f"First Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"Third Quartile (Q3): {q3}")
print(f"Maximum: {max_val}")
# Out:
# Minimum: 10.4
# First Quartile (Q1): 15.425
# Median (Q2): 19.2
# Third Quartile (Q3): 22.8
# Maximum: 33.9
